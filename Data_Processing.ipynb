# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
control = pd.read_csv("./data/control.csv")
control1 = pd.read_csv("./data/control.csv")
control
# Out:
#   Testers  Sleep duration  Snoring frequency  Snoring duration  Age Sex  \
# 0      a1             423                 87               352   55   M
# 1      a2             567                 35               331   48   M
# 2      b1             511                 54               210   55   M
# 3      b2             398                 49                35   25   M
# 4      c1             432                 40                28   51   F
# 5      c2             412                 52                75   27   F
# 6      d1             567                 21                90   28   F
# 7      d2             587                 18               330   47   M
# 8      d3             532                  9               282   48   M
# 9      e1             555                125               378   56   M
#
#    Height  Weight
# 0     173      88
# 1     177     105
# 2     178      90
# 3     174      66
# 4     159      53
# 5     168      56
# 6     169      63
# 7     183      73
# ...

# %%
control.index=control['Testers']
a01_sleep = control.loc['a1', 'Sleep duration']
a02_sleep = control.loc['a2', 'Sleep duration']
b01_sleep = control.loc['b1', 'Sleep duration']
b02_sleep = control.loc['b2', 'Sleep duration']
c01_sleep = control.loc['c1', 'Sleep duration']
c02_sleep = control.loc['c2', 'Sleep duration']
d01_sleep = control.loc['d1', 'Sleep duration']
d02_sleep = control.loc['d2', 'Sleep duration']
d03_sleep = control.loc['d3', 'Sleep duration']
e01_sleep = control.loc['e1', 'Sleep duration']

a01_sf = control.loc['a1','Snoring frequency']
a02_sf = control.loc['a2','Snoring frequency']
b01_sf = control.loc['b1','Snoring frequency']
b02_sf = control.loc['b2','Snoring frequency']
c01_sf = control.loc['c1','Snoring frequency']
c02_sf = control.loc['c2','Snoring frequency']
d01_sf = control.loc['d1','Snoring frequency']
d02_sf = control.loc['d2','Snoring frequency']
d03_sf = control.loc['d3','Snoring frequency']
e01_sf = control.loc['e1','Snoring frequency']

a01_sd = control.loc['a1','Snoring duration']
a02_sd = control.loc['a2','Snoring duration']
b01_sd = control.loc['b1','Snoring duration']
b02_sd = control.loc['b2','Snoring duration']
c01_sd = control.loc['c1','Snoring duration']
c02_sd = control.loc['c2','Snoring duration']
d01_sd = control.loc['d1','Snoring duration']
d02_sd = control.loc['d2','Snoring duration']
d03_sd = control.loc['d3','Snoring duration']
e01_sd = control.loc['e1','Snoring duration']

# %%
a1 = pd.read_csv("./data/a1.csv")
a1_date = a1["Date"]
a1_sleep = a1["Sleep duration"]
a1_feel = a1["Feeling"]
a1_sd = a1["Snoring duration"]
a1_sf = a1["Snoring frequency"]
a1
# Out:
#    Date  Sleep duration  Snoring frequency  Snoring duration  Price  Age Sex  \
# 0     1             370                 54               345      7   55   M
# 1     2             456                 43               333      7   55   M
# 2     3             450                 51               322      7   55   M
# 3     4             488                 43               312      7   55   M
# 4     5             560                 52               354      7   55   M
# 5     6             390                 43               245      7   55   M
# 6     7             499                 65               355      7   55   M
#
#    Height  Weight   Device  Feeling
# 0     173      88  Sticker        1
# 1     173      88  Sticker        1
# 2     173      88  Sticker        0
# 3     173      88  Sticker        1
# 4     173      88  Sticker        0
# 5     173      88  Sticker        1
# 6     173      88  Sticker        0

# %%
a2 = pd.read_csv("./data/a2.csv")
a2_date = a2["Date"]
a2_sleep = a2["Sleep duration"]
a2_feel = a2["Feeling"]
a2_sd = a2["Snoring duration"]
a2_sf = a2["Snoring frequency"]

# %%
b1 = pd.read_csv("./data/b1.csv")
b1_date = b1["Date"]
b1_sleep = b1["Sleep duration"]
b1_feel = b1["Feeling"]
b1_sd = b1["Snoring duration"]
b1_sf = b1["Snoring frequency"]

# %%
b2 = pd.read_csv("./data/b2.csv")
b2_date = b2["Date"]
b2_sleep = b2["Sleep duration"]
b2_feel = b2["Feeling"]
b2_sd = b2["Snoring duration"]
b2_sf = b2["Snoring frequency"]

# %%
c1 = pd.read_csv("./data/c1.csv")
c1_date = c1["Date"]
c1_sleep = c1["Sleep duration"]
c1_feel = c1["Feeling"]
c1_sd = c1["Snoring duration"]
c1_sf = c1["Snoring frequency"]

# %%
c2 = pd.read_csv("./data/c2.csv")
c2_date = c2["Date"]
c2_sleep = c2["Sleep duration"]
c2_feel = c2["Feeling"]
c2_sd = c2["Snoring duration"]
c2_sf = c2["Snoring frequency"]

# %%
d1 = pd.read_csv("./data/d1.csv")
d1_date = d1["Date"]
d1_sleep = d1["Sleep duration"]
d1_feel = d1["Feeling"]
d1_sd = d1["Snoring duration"]
d1_sf = d1["Snoring frequency"]

# %%
d2 = pd.read_csv("./data/d2.csv")
d2_date = d2["Date"]
d2_sleep = d2["Sleep duration"]
d2_feel = d2["Feeling"]
d2_sd = d2["Snoring duration"]
d2_sf = d2["Snoring frequency"]

# %%
d3 = pd.read_csv("./data/d3.csv")
d3_date = d3["Date"]
d3_sleep = d3["Sleep duration"]
d3_feel = d3["Feeling"]
d3_sd = d3["Snoring duration"]
d3_sf = d3["Snoring frequency"]

# %%
e1 = pd.read_csv("./data/e1.csv")
e1_date = e1["Date"]
e1_sleep = e1["Sleep duration"]
e1_feel = e1["Feeling"]
e1_sd = e1["Snoring duration"]
e1_sf = e1["Snoring frequency"]

# %%
figure, axes = plt.subplots(nrows=3, ncols=2, figsize=(20, 8), dpi=80)
plt.subplots_adjust(wspace =0.2, hspace =0.8)
axe = axes.flatten()

axe[0].plot(a1_date,a1_sleep, color="r", linestyle="-.", label="a1")
axe[0].plot(a2_date,a2_sleep, color="b", linestyle="-", label="a2")
axe[0].axhline(y=a01_sleep, color='r', linestyle=':', label="a1-control")
axe[0].axhline(y=a02_sleep, color='b', linestyle=':', label="a2-control")
axe[0].legend(fontsize=10,loc="upper right")
axe[1].plot(b1_date,b1_sleep, color="r", linestyle="-.", label="b1")
axe[1].plot(b2_date,b2_sleep, color="b", linestyle="-", label="b2")
axe[1].axhline(y=b01_sleep, color='r', linestyle=':', label="b1-control")
axe[1].axhline(y=b02_sleep, color='b', linestyle=':', label="b2-control")
axe[1].legend(fontsize=10,loc="upper right")
axe[2].plot(c1_date,c1_sleep, color="r", linestyle="-.", label="c1")
axe[2].plot(c2_date,c2_sleep, color="b", linestyle="-", label="c2")
axe[2].axhline(y=c01_sleep, color='r', linestyle=':', label="c1-control")
axe[2].axhline(y=c02_sleep, color='b', linestyle=':', label="c2-control")
axe[2].legend(fontsize=10,loc="upper right")
axe[3].plot(d1_date,d1_sleep, color="r", linestyle="-.", label="d1")
axe[3].plot(d2_date,d2_sleep, color="b", linestyle="-", label="d2")
axe[3].plot(d3_date,d3_sleep, color="g", linestyle="-", label="d3")
axe[3].axhline(y=d01_sleep, color='r', linestyle=':', label="d1-control")
axe[3].axhline(y=d02_sleep, color='b', linestyle=':', label="d2-control")
axe[3].axhline(y=d03_sleep, color='g', linestyle=':', label="d3-control")
axe[3].legend(fontsize=10,loc="upper right")
axe[4].plot(e1_date,e1_sleep, color="b", linestyle="-.", label="e1")
axe[4].axhline(y=e01_sleep, color='b', linestyle=':', label="e1-control")
axe[4].legend(fontsize=10,loc="upper right")
plt.delaxes(axes[2, 1])

x_label = ["Day{}".format(i) for i in range(1,8)]

axe[0].set_xticks(list(range(1,8)))
axe[0].set_xticklabels(x_label,size = 14)
axe[0].set_yticks(range(350,750,50))
axe[1].set_xticks(list(range(1,8)))
axe[1].set_xticklabels(x_label,size = 14)
axe[1].set_yticks(range(350,750,50))
axe[2].set_xticks(list(range(1,8)))
axe[2].set_xticklabels(x_label,size = 14)
axe[2].set_yticks(range(350,750,50))
axe[3].set_xticks(list(range(1,8)))
axe[3].set_xticklabels(x_label,size = 14)
axe[3].set_yticks(range(350,750,50))
axe[4].set_xticks(list(range(1,8)))
axe[4].set_xticklabels(x_label,size = 14)
axe[4].set_yticks(range(350,750,50))

axe[0].grid(linestyle="--", alpha=0.5)
axe[1].grid(linestyle="--", alpha=0.5)
axe[2].grid(linestyle="--", alpha=0.5)
axe[3].grid(linestyle="--", alpha=0.5)
axe[4].grid(linestyle="--", alpha=0.5)

axe[0].set_xlabel("Date",fontsize=20)
axe[0].set_ylabel("Sleep Duration",fontsize=20)
axe[0].set_title("Nose Sticker/Date-Sleep Duration",fontsize=20)
axe[1].set_xlabel("Date",fontsize=20)
axe[1].set_ylabel("Sleep Duration",fontsize=20)
axe[1].set_title("Anti-snoring pillow/Date-Sleep Duration",fontsize=20)
axe[2].set_xlabel("Date",fontsize=20)
axe[2].set_ylabel("Sleep Duration",fontsize=20)
axe[2].set_title("Face Band/Date-Sleep Duration",fontsize=20)
axe[3].set_xlabel("Date",fontsize=20)
axe[3].set_ylabel("Sleep Duration",fontsize=20)
axe[3].set_title("Nasal Spray/Date-Sleep Duration",fontsize=20)
axe[4].set_xlabel("Date",fontsize=20)
axe[4].set_ylabel("Sleep Duration",fontsize=20)
axe[4].set_title("Ventilator/Date-Sleep Duration",fontsize=20)

plt.savefig('./Sleep duration.jpg')

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
figure, axes = plt.subplots(nrows=3, ncols=2, figsize=(20, 8), dpi=80)
plt.subplots_adjust(wspace =0.2, hspace =0.8)
axe = axes.flatten()

axe[0].plot(a1_date,a1_sd, color="r", linestyle="-.", label="a1")
axe[0].plot(a2_date,a2_sd, color="b", linestyle="-", label="a2")
axe[0].axhline(y=a01_sd, color='r', linestyle=':', label="a1-control")
axe[0].axhline(y=a02_sd, color='b', linestyle=':', label="a2-control")
axe[0].legend(fontsize=10,loc="upper right")
axe[1].plot(b1_date,b1_sd, color="r", linestyle="-.", label="b1")
axe[1].plot(b2_date,b2_sd, color="b", linestyle="-", label="b2")
axe[1].axhline(y=b01_sd, color='r', linestyle=':', label="b1-control")
axe[1].axhline(y=b02_sd, color='b', linestyle=':', label="b2-control")
axe[1].legend(fontsize=10,loc="upper right")
axe[2].plot(c1_date,c1_sd, color="r", linestyle="-.", label="c1")
axe[2].plot(c2_date,c2_sd, color="b", linestyle="-", label="c2")
axe[2].axhline(y=c01_sd, color='r', linestyle=':', label="c1-control")
axe[2].axhline(y=c02_sd, color='b', linestyle=':', label="c2-control")
axe[2].legend(fontsize=10,loc="upper right")
axe[3].plot(d1_date,d1_sd, color="r", linestyle="-.", label="d1")
axe[3].plot(d2_date,d2_sd, color="b", linestyle="-", label="d2")
axe[3].plot(d3_date,d3_sd, color="g", linestyle="-", label="d3")
axe[3].axhline(y=d01_sd, color='r', linestyle=':', label="d1-control")
axe[3].axhline(y=d02_sd, color='b', linestyle=':', label="d2-control")
axe[3].axhline(y=d03_sd, color='g', linestyle=':', label="d3-control")
axe[3].legend(fontsize=10,loc="upper right")
axe[4].plot(e1_date,e1_sd, color="b", linestyle="-.", label="e1")
axe[4].axhline(y=e01_sd, color='b', linestyle=':', label="e1-control")
axe[4].legend(fontsize=10,loc="upper right")
plt.delaxes(axes[2, 1])

x_label = ["Day{}".format(i) for i in range(1,8)]

axe[0].set_xticks(list(range(1,8)))
axe[0].set_xticklabels(x_label,size = 14)
axe[0].set_yticks(range(200,450,50))
axe[1].set_xticks(list(range(1,8)))
axe[1].set_xticklabels(x_label,size = 14)
axe[1].set_yticks(range(0,300,50))
axe[2].set_xticks(list(range(1,8)))
axe[2].set_xticklabels(x_label,size = 14)
axe[2].set_yticks(range(0,150,50))
axe[3].set_xticks(list(range(1,8)))
axe[3].set_xticklabels(x_label,size = 14)
axe[3].set_yticks(range(0,400,50))
axe[4].set_xticks(list(range(1,8)))
axe[4].set_xticklabels(x_label,size = 14)
axe[4].set_yticks(range(250,450,50))

axe[0].grid(linestyle="--", alpha=0.5)
axe[1].grid(linestyle="--", alpha=0.5)
axe[2].grid(linestyle="--", alpha=0.5)
axe[3].grid(linestyle="--", alpha=0.5)
axe[4].grid(linestyle="--", alpha=0.5)

axe[0].set_xlabel("Date",fontsize=20)
axe[0].set_ylabel("Snoring duration",fontsize=18)
axe[0].set_title("Nose Sticker/Date-Snoring duration",fontsize=20)
axe[1].set_xlabel("Date",fontsize=20)
axe[1].set_ylabel("Snoring duration",fontsize=18)
axe[1].set_title("Anti-snoring pillow/Date-Snoring duration",fontsize=20)
axe[2].set_xlabel("Date",fontsize=20)
axe[2].set_ylabel("Snoring duration",fontsize=18)
axe[2].set_title("Face Band/Date-Snoring duration",fontsize=20)
axe[3].set_xlabel("Date",fontsize=20)
axe[3].set_ylabel("Snoring duration",fontsize=18)
axe[3].set_title("Nasal Spray/Date-Snoring duration",fontsize=20)
axe[4].set_xlabel("Date",fontsize=20)
axe[4].set_ylabel("Snoring duration",fontsize=18)
axe[4].set_title("Ventilator/Date-Snoring duration",fontsize=20)

plt.savefig('./Snoring duration.jpg')

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
figure, axes = plt.subplots(nrows=3, ncols=2, figsize=(20, 8), dpi=80)
plt.subplots_adjust(wspace =0.2, hspace =0.8)
axe = axes.flatten()

axe[0].plot(a1_date,a1_sf, color="r", linestyle="-.", label="a1")
axe[0].plot(a2_date,a2_sf, color="b", linestyle="-", label="a2")
axe[0].axhline(y=a01_sf, color='r', linestyle=':', label="a1-control")
axe[0].axhline(y=a02_sf, color='b', linestyle=':', label="a2-control")
axe[0].legend(fontsize=10,loc="upper right")
axe[1].plot(b1_date,b1_sf, color="r", linestyle="-.", label="b1")
axe[1].plot(b2_date,b2_sf, color="b", linestyle="-", label="b2")
axe[1].axhline(y=b01_sf, color='r', linestyle=':', label="b1-control")
axe[1].axhline(y=b02_sf, color='b', linestyle=':', label="b2-control")
axe[1].legend(fontsize=10,loc="upper right")
axe[2].plot(c1_date,c1_sf, color="r", linestyle="-.", label="c1")
axe[2].plot(c2_date,c2_sf, color="b", linestyle="-", label="c2")
axe[2].axhline(y=c01_sf, color='r', linestyle=':', label="c1-control")
axe[2].axhline(y=c02_sf, color='b', linestyle=':', label="c2-control")
axe[2].legend(fontsize=10,loc="upper right")
axe[3].plot(d1_date,d1_sf, color="r", linestyle="-.", label="d1")
axe[3].plot(d2_date,d2_sf, color="b", linestyle="-", label="d2")
axe[3].plot(d3_date,d3_sf, color="g", linestyle="-", label="d3")
axe[3].axhline(y=d01_sf, color='r', linestyle=':', label="d1-control")
axe[3].axhline(y=d02_sf, color='b', linestyle=':', label="d2-control")
axe[3].axhline(y=d03_sf, color='g', linestyle=':', label="d3-control")
axe[3].legend(fontsize=10,loc="upper right")
axe[4].plot(e1_date,e1_sf, color="b", linestyle="-.", label="e1")
axe[4].axhline(y=e01_sf, color='b', linestyle=':', label="e1-control")
axe[4].legend(fontsize=10,loc="upper right")
plt.delaxes(axes[2, 1])

x_label = ["Day{}".format(i) for i in range(1,8)]

axe[0].set_xticks(list(range(1,8)))
axe[0].set_xticklabels(x_label,size = 14)
axe[0].set_yticks(range(0,150,50))
axe[1].set_xticks(list(range(1,8)))
axe[1].set_xticklabels(x_label,size = 14)
axe[1].set_yticks(range(0,150,50))
axe[2].set_xticks(list(range(1,8)))
axe[2].set_xticklabels(x_label,size = 14)
axe[2].set_yticks(range(0,150,50))
axe[3].set_xticks(list(range(1,8)))
axe[3].set_xticklabels(x_label,size = 14)
axe[3].set_yticks(range(0,100,50))
axe[4].set_xticks(list(range(1,8)))
axe[4].set_xticklabels(x_label,size = 14)
axe[4].set_yticks(range(50,200,50))

axe[0].grid(linestyle="--", alpha=0.5)
axe[1].grid(linestyle="--", alpha=0.5)
axe[2].grid(linestyle="--", alpha=0.5)
axe[3].grid(linestyle="--", alpha=0.5)
axe[4].grid(linestyle="--", alpha=0.5)

axe[0].set_xlabel("Date",fontsize=20)
axe[0].set_ylabel("Snoring frequency",fontsize=18)
axe[0].set_title("Nose Sticker/Date-Snoring frequency",fontsize=20)
axe[1].set_xlabel("Date",fontsize=20)
axe[1].set_ylabel("Snoring frequency",fontsize=18)
axe[1].set_title("Anti-snoring pillow/Date-Snoring frequency",fontsize=20)
axe[2].set_xlabel("Date",fontsize=20)
axe[2].set_ylabel("Snoring frequency",fontsize=18)
axe[2].set_title("Face Band/Date-Snoring frequency",fontsize=20)
axe[3].set_xlabel("Date",fontsize=20)
axe[3].set_ylabel("Snoring frequency",fontsize=18)
axe[3].set_title("Nasal Spray/Date-Snoring frequency",fontsize=20)
axe[4].set_xlabel("Date",fontsize=20)
axe[4].set_ylabel("Snoring frequency",fontsize=18)
axe[4].set_title("Ventilator/Date-Snoring frequency",fontsize=20)

plt.savefig('./Snoring frequency.jpg')

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
def polyfit(date,feel):
    z1 = np.polyfit(date,feel,3)
    p1= np.poly1d(z1)
    date_feel_vals = p1(date)
    return date_feel_vals

# %%
plt.figure(figsize = (20,8), dpi = 80)

a1_polyfit_values = polyfit(a1_date,a1_feel)
a2_polyfit_values = polyfit(a1_date,a2_feel)
b1_polyfit_values = polyfit(a1_date,b1_feel)
b2_polyfit_values = polyfit(a1_date,b2_feel)
c1_polyfit_values = polyfit(a1_date,c1_feel)
c2_polyfit_values = polyfit(a1_date,c2_feel)
d1_polyfit_values = polyfit(a1_date,d1_feel)
d2_polyfit_values = polyfit(a1_date,d2_feel)
d3_polyfit_values = polyfit(a1_date,d3_feel)
e1_polyfit_values = polyfit(a1_date,e1_feel)

plt.plot(a1_date,a1_polyfit_values, color="r", linestyle="-", label="Nose Sticker-a1")
plt.plot(a1_date,a2_polyfit_values, color="r", linestyle="-", label="Nose Sticker-a2")
plt.plot(a1_date,b1_polyfit_values, color="b", linestyle="-.", label="Anti-snoring pillow-b1")
plt.plot(a1_date,b2_polyfit_values, color="b", linestyle="-.", label="Anti-snoring pillow-b2")
plt.plot(a1_date,c1_polyfit_values, color="g", linestyle=":", label="Face Band-c1")
plt.plot(a1_date,c2_polyfit_values, color="g", linestyle=":", label="Face Band-c2")
plt.plot(a1_date,d1_polyfit_values, color="y", linestyle="--", label="Nasal Spray-d1")
plt.plot(a1_date,d2_polyfit_values, color="y", linestyle="--", label="Nasal Spray-d2")
plt.plot(a1_date,d3_polyfit_values, color="y", linestyle="--", label="Nasal Spray-d3")
plt.plot(a1_date,e1_polyfit_values, color="k", linestyle="-", label="Ventilator-e1")

plt.legend(loc="upper left",fontsize=14)

x_label = ["Day{}".format(i) for i in range(1,8)]

plt.xticks(range(1,8), labels = x_label, size = 14)
plt.yticks([0, 1, 2],['Not working','Slow down','Efficient'],size = 14)

plt.grid(linestyle="--", alpha=0.5)

plt.xlabel("Date",fontsize=20)
plt.ylabel("Feeling after use",fontsize=20)
plt.title("Date-Feeling after use",fontsize=20)

plt.savefig('./Feeling.jpg')

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
control1= control1.drop('Sex', 1)
control1= control1.drop('Height', 1)
control1= control1.drop('Testers', 1)
# Out:
# C:\ProgramData\Anaconda3\envs\pytorch-gpu\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   """Entry point for launching an IPython kernel.
# C:\ProgramData\Anaconda3\envs\pytorch-gpu\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#
# C:\ProgramData\Anaconda3\envs\pytorch-gpu\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
control1
# Out:
#    Sleep duration  Snoring frequency  Snoring duration  Age  Weight
# 0             423                 87               352   55      88
# 1             567                 35               331   48     105
# 2             511                 54               210   55      90
# 3             398                 49                35   25      66
# 4             432                 40                28   51      53
# 5             412                 52                75   27      56
# 6             567                 21                90   28      63
# 7             587                 18               330   47      73
# 8             532                  9               282   48      68
# 9             555                125               378   56      16

# %%
print(control1.corr())
fig = pd.plotting.scatter_matrix(control1,figsize=(9,9),c ='blue',marker = 'o',diagonal='',alpha = 0.8,range_padding=0.2)
plt.savefig('./correlation0.jpg')
plt.show()
# Out:
#                    Sleep duration  Snoring frequency  Snoring duration  \
# Sleep duration           1.000000          -0.221509          0.566261
# Snoring frequency       -0.221509           1.000000          0.327814
# Snoring duration         0.566261           0.327814          1.000000
# Age                      0.299807           0.363689          0.697901
# Weight                   0.042808          -0.459663          0.144483
#
#                         Age    Weight
# Sleep duration     0.299807  0.042808
# Snoring frequency  0.363689 -0.459663
# Snoring duration   0.697901  0.144483
# Age                1.000000  0.079952
# Weight             0.079952  1.000000

# %%
new =pd.DataFrame({'age': [55,48,55,25,51,27,28,47,48,56], 
                   'weight': [88,105,90,66,53,56,63,73,68,116],
                   'Sleepingduration':[a1_sleep.mean(),a2_sleep.mean(),b1_sleep.mean(),b2_sleep.mean(),c1_sleep.mean(),c2_sleep.mean(),d1_sleep.mean(),d2_sleep.mean(),d3_sleep.mean(),e1_sleep.mean()],
                   'Snoringduration':[a1_sd.mean(),a2_sd.mean(),b1_sd.mean(),b2_sd.mean(),c1_sd.mean(),c2_sd.mean(),d1_sd.mean(),d2_sd.mean(),d3_sd.mean(),e1_sd.mean()],
                  'Snoring frequency':[a1_sf.mean(),a2_sf.mean(),b1_sf.mean(),b2_sf.mean(),c1_sf.mean(),c2_sf.mean(),d1_sf.mean(),d2_sf.mean(),d3_sf.mean(),e1_sf.mean()]})
new
# Out:
#    age  weight  Sleepingduration  Snoringduration  Snoring frequency
# 0   55      88        459.000000       323.714286          50.142857
# 1   48     105        545.857143       321.857143          34.571429
# 2   55      90        513.428571       189.428571          24.000000
# 3   25      66        452.714286        36.000000          41.571429
# 4   51      53        485.428571        28.428571          42.285714
# 5   27      56        512.000000        54.285714          35.285714
# 6   28      63        501.285714        64.142857          15.571429
# 7   47      73        547.285714       323.571429          27.285714
# 8   48      68        513.714286       245.428571          16.714286
# 9   56     116        516.571429       294.142857          96.428571

# %%
print(new.corr())
fig = pd.plotting.scatter_matrix(new,figsize=(9,9),c ='blue',marker = 'o',diagonal='',alpha = 0.8,range_padding=0.2)
plt.savefig('./correlation1.jpg')
plt.show()
# Out:
#                         age    weight  Sleepingduration  Snoringduration  \
# age                1.000000  0.601632          0.239885         0.690699
# weight             0.601632  1.000000          0.315863         0.745988
# Sleepingduration   0.239885  0.315863          1.000000         0.468164
# Snoringduration    0.690699  0.745988          0.468164         1.000000
# Snoring frequency  0.353159  0.585980         -0.148305         0.243506
#
#                    Snoring frequency
# age                         0.353159
# weight                      0.585980
# Sleepingduration           -0.148305
# Snoringduration             0.243506
# Snoring frequency           1.000000

# %%
a1_new = a1.append([{'Sleep duration':a01_sleep,'Snoring frequency':a01_sf,'Snoring duration':a01_sd}], ignore_index=True)
a1_new
# Out:
#    Date  Sleep duration  Snoring frequency  Snoring duration  Price   Age  \
# 0   1.0             370                 54               345    7.0  55.0
# 1   2.0             456                 43               333    7.0  55.0
# 2   3.0             450                 51               322    7.0  55.0
# 3   4.0             488                 43               312    7.0  55.0
# 4   5.0             560                 52               354    7.0  55.0
# 5   6.0             390                 43               245    7.0  55.0
# 6   7.0             499                 65               355    7.0  55.0
# 7   NaN             423                 87               352    NaN   NaN
#
#    Sex  Height  Weight   Device  Feeling
# 0    M   173.0    88.0  Sticker      1.0
# 1    M   173.0    88.0  Sticker      1.0
# 2    M   173.0    88.0  Sticker      0.0
# 3    M   173.0    88.0  Sticker      1.0
# 4    M   173.0    88.0  Sticker      0.0
# 5    M   173.0    88.0  Sticker      1.0
# ...

# %%
a2_new = a2.append([{'Sleep duration':a02_sleep,'Snoring frequency':a02_sf,'Snoring duration':a02_sd}], ignore_index=True)
b1_new = b1.append([{'Sleep duration':b01_sleep,'Snoring frequency':b01_sf,'Snoring duration':b01_sd}], ignore_index=True)
b2_new = b2.append([{'Sleep duration':b02_sleep,'Snoring frequency':b02_sf,'Snoring duration':b02_sd}], ignore_index=True)
c1_new = c1.append([{'Sleep duration':c01_sleep,'Snoring frequency':c01_sf,'Snoring duration':c01_sd}], ignore_index=True)
c2_new = c2.append([{'Sleep duration':c02_sleep,'Snoring frequency':c02_sf,'Snoring duration':c02_sd}], ignore_index=True)
d1_new = d1.append([{'Sleep duration':d01_sleep,'Snoring frequency':d01_sf,'Snoring duration':d01_sd}], ignore_index=True)
d2_new = d2.append([{'Sleep duration':d02_sleep,'Snoring frequency':d02_sf,'Snoring duration':d02_sd}], ignore_index=True)
d3_new = d3.append([{'Sleep duration':d03_sleep,'Snoring frequency':d03_sf,'Snoring duration':d03_sd}], ignore_index=True)
e1_new = e1.append([{'Sleep duration':e01_sleep,'Snoring frequency':e01_sf,'Snoring duration':e01_sd}], ignore_index=True)

# %%
def normalization(data):
    data_norm = (data - data.min()) / (data.max() - data.min())
    delta = data_norm[7]-data_norm[:7].mean()
    return delta

# %%
a1_dif = normalization(a1_new['Snoring frequency']) - normalization(a1_new['Sleep duration']) + normalization(a1_new['Snoring duration'])
a2_dif = normalization(a2_new['Snoring frequency']) - normalization(a2_new['Sleep duration']) + normalization(a2_new['Snoring duration'])
b1_dif = normalization(b1_new['Snoring frequency']) - normalization(b1_new['Sleep duration']) + normalization(b1_new['Snoring duration'])
b2_dif = normalization(b2_new['Snoring frequency']) - normalization(b2_new['Sleep duration']) + normalization(b2_new['Snoring duration'])
c1_dif = normalization(c1_new['Snoring frequency']) - normalization(c1_new['Sleep duration']) + normalization(c1_new['Snoring duration'])
c2_dif = normalization(c2_new['Snoring frequency']) - normalization(c2_new['Sleep duration']) + normalization(c2_new['Snoring duration'])
d1_dif = normalization(d1_new['Snoring frequency']) - normalization(d1_new['Sleep duration']) + normalization(d1_new['Snoring duration'])
d2_dif = normalization(d2_new['Snoring frequency']) - normalization(d2_new['Sleep duration']) + normalization(d2_new['Snoring duration'])
d3_dif = normalization(d3_new['Snoring frequency']) - normalization(d3_new['Sleep duration']) + normalization(d3_new['Snoring duration'])
e1_dif = normalization(e1_new['Snoring frequency']) - normalization(e1_new['Sleep duration']) + normalization(e1_new['Snoring duration'])

# %%
plt.figure(figsize = (20,8), dpi = 80)

plt.scatter(a1['Price'].mean(),a1_dif, color="r", marker="o", label="Nose Sticker")
plt.scatter(a2['Price'].mean(),a2_dif, color="r", marker="o", label="Nose Sticker")
plt.scatter(b1['Price'].mean(),b1_dif, color="b", marker="v", label="Anti-snoring pillow")
plt.scatter(b2['Price'].mean(),b2_dif, color="b", marker="v", label="Anti-snoring pillow")
plt.scatter(c1['Price'].mean(),c1_dif, color="g", marker="s", label="Face Band")
plt.scatter(c2['Price'].mean(),c2_dif, color="g", marker="s", label="Face Band")
plt.scatter(d1['Price'].mean(),d1_dif, color="y", marker="D", label="Nasal Spray")
plt.scatter(d2['Price'].mean(),d2_dif, color="y", marker="D", label="Nasal Spray")
plt.scatter(d3['Price'].mean(),d3_dif, color="y", marker="D", label="Nasal Spray")
#plt.scatter(e1['Price'].mean(),e1_dif, color="k", marker="*", label="Ventilator")


plt.legend(loc="lower right",fontsize=14)

plt.grid(linestyle="--", alpha=0.5)

plt.xlabel("Price",fontsize=20)
plt.ylabel("Performance",fontsize=20)
plt.title("Price–Performance",fontsize=20)

plt.savefig('./Price–Performance.jpg')

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
